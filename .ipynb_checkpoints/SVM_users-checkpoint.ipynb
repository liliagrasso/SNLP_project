# %% [markdown]
# ### Grouping for users and predicting the users characteristics by text of the debates

# %%
from sklearn import metrics
from scipy.sparse import hstack
from sklearn.metrics import f1_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from collections import defaultdict
from sklearn.metrics import roc_auc_score
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from collections import defaultdict
from nltk.corpus import wordnet as wn
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, svm 
from sklearn.metrics import accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings
warnings.filterwarnings("ignore")

# %%
text=pd.read_csv("non_tokenized.csv")

# %%
text.head()
# Out:
#    Unnamed: 0                                               text   user side  \
# 0           0  Some context on the resolution. Normally I wou...  Mikal  Pro
# 1           1  We can dismiss most everything in his last rou...  Mikal  Pro
# 2           2  On to rebuttals1) IntroI'm not sure what he is...  Mikal  Pro
# 3           3  This is a debate challenge to Cassie on a foru...  Mikal  Con
# 4           4  Resending this to Zaro as this was intended fo...  Mikal  Con
#
#         category                                              title    url  \
# 0  Miscellaneous  Covenys recent behavior would be a net detrime...  Mikal
# 1  Miscellaneous  Covenys recent behavior would be a net detrime...  Mikal
# 2  Miscellaneous  Covenys recent behavior would be a net detrime...  Mikal
# 3       Politics                      Islam is a civilized religion  Mikal
# 4       Politics                      Islam is a civilized religion  Mikal
#
#   ideology        party gender ethnicity      religion  win_ratio
# 0    Right  Independent   Male     White  Non Believer     0.9684
# 1    Right  Independent   Male     White  Non Believer     0.9684
# 2    Right  Independent   Male     White  Non Believer     0.9684
# 3    Right  Independent   Male     White  Non Believer     0.9684
# 4    Right  Independent   Male     White  Non Believer     0.9684

# %%
per_users=text[["text","user","ideology","party","gender","ethnicity","religion"]]

# %%
per_users.dropna(inplace=True)
per_users=per_users.groupby(["user","ideology","party","gender","ethnicity","religion"],as_index=False)["text"].apply(lambda x: ' '.join(x))

# %%
per_users
# Out:
#                   user ideology             party  gender       ethnicity  \
# 0              0905845    Other  Republican Party  Female           White
# 1               091915    Other       Independent  Female           White
# 2                10438    Other       Independent  Female           White
# 3               105060    Other             Other    Male           White
# 4     11BangBangEnvyme    Right  Democratic Party    Male           White
# ...                ...      ...               ...     ...             ...
# 3961         zneuser93   Center  Democratic Party    Male           White
# 3962       zobothehobo     Left  Democratic Party  Female  Middle Eastern
# 3963          zoetwinn     Left  Democratic Party  Female           White
# 3964        zorasbrown   Center  Democratic Party    Male           Asian
# 3965       zwalker0412     Left             Other    Male           Asian
#
#           religion                                               text
# 0        Christian          alright, let's go!\n\r\nyou can go first!
# 1        Christian  Hello, I want to start off with the fact that ...
# 2        Christian  Pageants are performances, in every meaning of...
# 3     Non Believer  I sincerely believe it is possible.I, personal...
# 4        Christian  Obama is the best choice for president. Mitt R...
# ...            ...                                                ...
# 3961     Christian  My band:\r\n1:MC: Tupac http://en.wikipedia.or...
# 3962  Non Believer  I don't believe texting in class is THAT bad. ...
# 3963  Non Believer  First round is acceptance. Preferably my oppon...
# 3964     Christian  dear con . thers no sound without a listener ....
# 3965     Christian  A woman should not be expected to perform hous...
#
# [3966 rows x 7 columns]

# %%
#per_users=per_users.sample(n=1000)

# %%
#per_users=per_users.reset_index()

# %%
# Step - a : Remove blank rows if any.
per_users['text'].dropna(inplace=True)
# Step - b : Change all the text to lower case. This is required as python interprets 'dog' and 'DOG' differently
per_users['text_final'] = [entry.lower() for entry in per_users['text']]
# Step - c : Tokenization : In this each entry in the corpus will be broken into set of words
per_users['text_final']= [word_tokenize(entry) for entry in per_users['text_final']]
# Step - d : Remove Stop words, Non-Numeric and perfom Word Stemming/Lemmenting.
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV
for index,entry in enumerate(per_users['text_final']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'title_final'
    per_users.loc[index,'text_final'] = str(Final_words)

# %% [markdown]
# Dataset has target variables with high imbalanced classes!! We have to solve this

# %%
random.seed(500)

# %%
#dividing in train (70% of the dataset) and test set (30% of the dataset)
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(per_users['text_final'],per_users[['gender','religion','ethnicity','ideology']],test_size=0.3)

# %%
Encoder = LabelEncoder()

#word vectorization
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(per_users["text_final"])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

# %%
#Label encode the target variable — 
#This is done to transform Categorical data of string type in the data set 
#into numerical values which the model can understand.

#gender
Train_Y_gender = Encoder.fit_transform(Train_Y['gender'])
Test_Y_gender = Encoder.fit_transform(Test_Y['gender'])

#religion
Train_Y_rel = Encoder.fit_transform(Train_Y['religion'])
Test_Y_rel = Encoder.fit_transform(Test_Y['religion'])

#ethnicity
Train_Y_ethn = Encoder.fit_transform(Train_Y['ethnicity'])
Test_Y_ethn = Encoder.fit_transform(Test_Y['ethnicity'])

#ideology
Train_Y_id = Encoder.fit_transform(Train_Y['ideology'])
Test_Y_id = Encoder.fit_transform(Test_Y['ideology'])

#stacking into a vector
y_train=np.stack((Train_Y_gender,Train_Y_rel,Train_Y_ethn,Train_Y_id),axis=1)
y_test=np.stack((Test_Y_gender,Test_Y_rel,Test_Y_ethn,Test_Y_id),axis=1)

# %%
#using we can use the argument class_weight='balanced'  
#to penalize mistakes on the minority class by an amount proportional to how under-represented it is.
SVM = svm.SVC(C=1.0, kernel='linear',class_weight='balanced', gamma='auto',decision_function_shape='ovo',probability=True)
# Create the Multioutput Classifier
mor = MultiOutputClassifier(SVM)
# Train the regressor
mor.fit(Train_X_Tfidf, y_train)
# Generate predictions for testing data
y_pred = mor.predict(Test_X_Tfidf)

# %%
print("SVM Metrics for Gender")
print(f"The F1 score is {f1_score(y_test[:,0], y_pred[:,0], average='weighted')}")
# Out:
# SVM Metrics for Gender
# The F1 score is 0.7335790517995534

# %%
# What about AUROC?
print(roc_auc_score(y_test[:,0],mor.predict_proba(Test_X_Tfidf)[0],  multi_class='ovo') )
# Out:
# 0.6902146927721041

# %%
#i-th row and j-th column entry indicates the number of samples with true label being i-th class and predicted label being j-th class.
metrics.confusion_matrix(y_test[:,0], y_pred[:,0])
# Out:
# array([[126,   0,  96],
#        [  3,   2,   5],
#        [239,   0, 719]], dtype=int64)

# %%
print("SVM Metrics for Religion")
print(f"The F1 score is {f1_score(y_test[:,1], y_pred[:,1], average='weighted')}")
# Out:
# SVM Metrics for Religion
# The F1 score is 0.47875473174941313

# %%
# What about AUROC?
print(roc_auc_score(y_test[:,1],mor.predict_proba(Test_X_Tfidf)[1],  multi_class='ovo') )
# Out:
# 0.6645963550330932

# %%
metrics.confusion_matrix(y_test[:,1], y_pred[:,1])
# Out:
# array([[300,   6, 137,  85],
#        [  3,   4,   4,   4],
#        [143,   6, 211,  80],
#        [ 65,   1,  89,  52]], dtype=int64)

# %%
print("SVM Metrics for Ethnicity")
print(f"The F1 score is {f1_score(y_test[:,2], y_pred[:,2], average='weighted')}")
# Out:
# SVM Metrics for Ethnicity
# The F1 score is 0.4998907259918077

# %%
# What about AUROC?
#print(roc_auc_score(y_test[:,2],mor.predict_proba(Test_X_Tfidf)[2],  multi_class='ovo') )
metrics.confusion_matrix(y_test[:,2], y_pred[:,2])
# Out:
# array([[ 16,   4,   1,  13,   1,   3,   9,   0,  36],
#        [  7,  15,   1,   4,   1,   1,   9,   0,  20],
#        [  2,   0,   0,   1,   0,   0,   2,   0,   4],
#        [ 13,   5,   0,   4,   0,   1,   5,   0,  34],
#        [  4,   3,   0,   2,   0,   0,   3,   0,   5],
#        [  2,   0,   0,   1,   0,   1,   2,   0,   3],
#        [ 11,   5,   0,   7,   1,   0,  12,   0,  31],
#        [  4,   0,   0,   1,   0,   0,   1,   0,   0],
#        [132,  93,   1,  67,   4,   5,  98,   1, 478]], dtype=int64)

# %%
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score Ideology")
print(f"The F1 score is {f1_score(y_test[:,3], y_pred[:,3], average='weighted')}")
# Out:
# SVM Accuracy Score Ideology
# The F1 score is 0.35941501897798134

# %%
# What about AUROC?
print(roc_auc_score(y_test[:,3],mor.predict_proba(Test_X_Tfidf)[3],  multi_class='ovo') )
# Out:
# 0.5702566607321674

# %%
metrics.confusion_matrix(y_test[:,3], y_pred[:,3])
# Out:
# array([[ 46,  32,  57,  60],
#        [ 41,  36,  46,  41],
#        [ 62,  43,  88,  53],
#        [119, 100, 132, 234]], dtype=int64)

# %% [markdown]
# ### Dividing Dataset into two dataset, one with text length higher than the median, the other with text length lower than the median

# %%
def length(x):
    l=0
    for i in x:
        for j in i:
            l+=len(j)
            
    return l

per_users["text_length"]=per_users["text"].apply(length)

# %%
val_med=int(np.median(per_users["text_length"]))

#dividing the dataset into two model
#Model 1: text_length>val_med
#Model 1: text_length>val_med

per_users_high=per_users[per_users["text_length"]>val_med].reset_index()
per_users_low=per_users[per_users["text_length"]<val_med].reset_index()

# %%
#dividing in train (70% of the dataset) and test set (30% of the dataset)
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(per_users_high['text_final'],per_users_high[['gender','religion','ethnicity','ideology']],test_size=0.3)

# %%
Encoder = LabelEncoder()

#word vectorization
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(per_users_high["text_final"])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

# %%
#Label encode the target variable — 
#This is done to transform Categorical data of string type in the data set 
#into numerical values which the model can understand.

#gender
Train_Y_gender = Encoder.fit_transform(Train_Y['gender'])
Test_Y_gender = Encoder.fit_transform(Test_Y['gender'])

#religion
Train_Y_rel = Encoder.fit_transform(Train_Y['religion'])
Test_Y_rel = Encoder.fit_transform(Test_Y['religion'])

#ethnicity
Train_Y_ethn = Encoder.fit_transform(Train_Y['ethnicity'])
Test_Y_ethn = Encoder.fit_transform(Test_Y['ethnicity'])

#ideology
Train_Y_id = Encoder.fit_transform(Train_Y['ideology'])
Test_Y_id = Encoder.fit_transform(Test_Y['ideology'])

#stacking into a vector
y_train=np.stack((Train_Y_gender,Train_Y_rel,Train_Y_ethn,Train_Y_id),axis=1)
y_test=np.stack((Test_Y_gender,Test_Y_rel,Test_Y_ethn,Test_Y_id),axis=1)

# %%
#using we can use the argument class_weight='balanced'  
#to penalize mistakes on the minority class by an amount proportional to how under-represented it is.
SVM = svm.SVC(C=1.0, kernel='linear',class_weight='balanced',gamma='auto', decision_function_shape='ovo',probability=True)
# Create the Multioutput Classifier
mor = MultiOutputClassifier(SVM)
# Train the regressor
mor.fit(Train_X_Tfidf, y_train)
# Generate predictions for testing data
y_pred = mor.predict(Test_X_Tfidf)

# %%
print("SVM Metrics for Gender")
print(f"The F1 score is {f1_score(y_test[:,0], y_pred[:,0], average='weighted')}")
# Out:
# SVM Metrics for Gender
# The F1 score is 0.8227234949924026

# %%
print("SVM Metrics for Religion")
print(f"The F1 score is {f1_score(y_test[:,1], y_pred[:,1], average='weighted')}")
# Out:
# SVM Metrics for Religion
# The F1 score is 0.5066756492664141

# %%
metrics.confusion_matrix(y_test[:,1], y_pred[:,1])
# Out:
# array([[142,   3,  59,  41],
#        [  1,   3,   1,   1],
#        [ 74,   0, 135,  44],
#        [ 31,   0,  41,  19]], dtype=int64)

# %%
print("SVM Metrics for Ethnicity")
print(f"The F1 score is {f1_score(y_test[:,2], y_pred[:,2], average='weighted')}")
# Out:
# SVM Metrics for Ethnicity
# The F1 score is 0.5523901445257401

# %%
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score Ideology")
print(f"The F1 score is {f1_score(y_test[:,3], y_pred[:,3], average='weighted')}")
# Out:
# SVM Accuracy Score Ideology
# The F1 score is 0.3788443639795337

# %%
#dividing in train (70% of the dataset) and test set (30% of the dataset)
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(per_users_low['text_final'],per_users_low[['gender','religion','ethnicity','ideology']],test_size=0.3)

# %%
Encoder = LabelEncoder()

#word vectorization
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(per_users_low["text_final"])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

# %%
#Label encode the target variable — 
#This is done to transform Categorical data of string type in the data set 
#into numerical values which the model can understand.

#gender
Train_Y_gender = Encoder.fit_transform(Train_Y['gender'])
Test_Y_gender = Encoder.fit_transform(Test_Y['gender'])

#religion
Train_Y_rel = Encoder.fit_transform(Train_Y['religion'])
Test_Y_rel = Encoder.fit_transform(Test_Y['religion'])

#ethnicity
Train_Y_ethn = Encoder.fit_transform(Train_Y['ethnicity'])
Test_Y_ethn = Encoder.fit_transform(Test_Y['ethnicity'])

#ideology
Train_Y_id = Encoder.fit_transform(Train_Y['ideology'])
Test_Y_id = Encoder.fit_transform(Test_Y['ideology'])

#stacking into a vector
y_train=np.stack((Train_Y_gender,Train_Y_rel,Train_Y_ethn,Train_Y_id),axis=1)
y_test=np.stack((Test_Y_gender,Test_Y_rel,Test_Y_ethn,Test_Y_id),axis=1)

# %%
#using we can use the argument class_weight='balanced'  
#to penalize mistakes on the minority class by an amount proportional to how under-represented it is.
SVM = svm.SVC(C=1.0, kernel='linear',class_weight='balanced',gamma='auto',probability=True)
# Create the Multioutput Classifier
mor = MultiOutputClassifier(SVM)
# Train the regressor
mor.fit(Train_X_Tfidf, y_train)
# Generate predictions for testing data
y_pred = mor.predict(Test_X_Tfidf)

# %%
print("SVM Metrics for Gender")
print(f"The F1 score is {f1_score(y_test[:,0], y_pred[:,0], average='weighted')}")
# Out:
# SVM Metrics for Gender
# The F1 score is 0.6805063060542437

# %%
print("SVM Metrics for Religion")
print(f"The F1 score is {f1_score(y_test[:,1], y_pred[:,1], average='weighted')}")
# Out:
# SVM Metrics for Religion
# The F1 score is 0.4352633497603221

# %%
print("SVM Metrics for Ethnicity")
print(f"The F1 score is {f1_score(y_test[:,2], y_pred[:,2], average='weighted')}")
# Out:
# SVM Metrics for Ethnicity
# The F1 score is 0.5400533438121389

# %%
print("SVM Accuracy Score Ideology")
print(f"The F1 score is {f1_score(y_test[:,3], y_pred[:,3], average='weighted')}")
# Out:
# SVM Accuracy Score Ideology
# The F1 score is 0.31492099403570895

# %% [markdown]
# #### Adding the side and the title to the text columns

# %%
text.dropna(inplace=True)
first_gb=text.groupby(["title","user","side","ideology","party","gender","ethnicity","religion"],as_index=False)["text"].apply(lambda x: ' '.join(x))

# %%
first_gb
# Out:
#                                                    title             user  \
# 0      " If it looks like a duck, quacks like a duck ...         sadolite
# 1      " TV {prime time} tries to\r\n run head & head...       ruth421963
# 2      " inappropriate lyrics should be banned from t...  lifesaglitch911
# 3      ""God, as seen through the eyes of the biblica...        Dr_Harvey
# 4      ""God, as seen through the eyes of the biblica...      Ragnar_Rahl
# ...                                                  ...              ...
# 30380                   zombies are better than vampires      nerdykiller
# 30381                                               zoos         RacH3ll3
# 30382  ~One Sentence Debate~ Legend of Zelda: Ocarina...         Bran_man
# 30383  ~One Sentence Debate~ Legend of Zelda: Ocarina...      maninorange
# 30384              •Should juveniles be tried as adults?    debategirl111
#
#       side ideology                    party  gender ethnicity      religion  \
# 0      Pro    Other                    Other    Male     Other         Other
# 1      Con    Right         Democratic Party  Female     White     Christian
# 2      Con    Right         Republican Party    Male     White     Christian
# 3      Con    Right  Peace and Freedom Party    Male     White     Christian
# 4      Pro    Right                Undecided    Male     White  Non Believer
# ...    ...      ...                      ...     ...       ...           ...
# 30380  Con    Other                    Other    Male     Asian     Christian
# 30381  Pro    Other                Undecided  Female     White     Christian
# 30382  Pro    Right         Republican Party    Male     White     Christian
# 30383  Con    Right  Peace and Freedom Party    Male     White  Non Believer
# 30384  Con    Other                    Other  Female     Black     Christian
#
#                                                     text  \
# 0      We have all heard the phrase: " If it looks li...
# 1      Hey hi,\r\nI would love to gather\r\nother ppl...
# 2      Currently so called " inappropriate" language ...
# 3      I won't lie, your arguments were challenging a...
# 4      "Matthew 19:26\r\nBut Jesus beheld them, and s...
# ...                                                  ...
# 30380  Thank u for the rules.\r\nI believe round 1 is...
# 30381  hello :)\n\r\nwe are going to be arguing about...
# 30382  ~~~~\r\nTired of having to read such long deba...
# 30383  Neither memorable theme music/sound effects no...
# 30384  no they should not they are still kids they se...
#
#                                            complete_text
# 0      " If it looks like a duck, quacks like a duck ...
# 1      " TV {prime time} tries to\r\n run head & head...
# 2      " inappropriate lyrics should be banned from t...
# 3      ""God, as seen through the eyes of the biblica...
# 4      ""God, as seen through the eyes of the biblica...
# ...                                                  ...
# 30380  zombies are better than vampires-Con-Thank u f...
# 30381  zoos-Pro-hello :)\n\r\nwe are going to be argu...
# 30382  ~One Sentence Debate~ Legend of Zelda: Ocarina...
# 30383  ~One Sentence Debate~ Legend of Zelda: Ocarina...
# 30384  •Should juveniles be tried as adults?-Con-no t...
#
# [30385 rows x 10 columns]

# %%
#text.dropna(inplace=True)
first_gb["complete_text"]=first_gb[["title","side","text"]].agg('-'.join, axis=1)
second_gb=first_gb.groupby(["user","ideology","party","gender","ethnicity","religion"],as_index=False)["complete_text"].apply(lambda x: ' '.join(x))

# %%
second_gb.head()
# Out:
#                user ideology             party  gender ethnicity  \
# 0           0905845    Other  Republican Party  Female     White
# 1            091915    Other       Independent  Female     White
# 2             10438    Other       Independent  Female     White
# 3            105060    Other             Other    Male     White
# 4  11BangBangEnvyme    Right  Democratic Party    Male     White
#
#        religion                                      complete_text
# 0     Christian  Rap Battle 5 Cheesedingo VS 0905845-Con-alrigh...
# 1     Christian  does everything revolves around math?-Con-Hell...
# 2     Christian  Pageants are STUPID.-Con-Pageants are performa...
# 3  Non Believer  Is it possible to create an actual utopia?-Pro...
# 4     Christian  Obama is the best choice for president.-Pro-Ob...

# %%
second_gb.to_csv("users_text.csv")

# %%
sample=second_gb
#sample=sample.reset_index()

# %%
# Step - a : Remove blank rows if any.
sample['complete_text'].dropna(inplace=True)
# Step - b : Change all the text to lower case. This is required as python interprets 'dog' and 'DOG' differently
sample['text_final'] = [entry.lower() for entry in sample['complete_text']]
# Step - c : Tokenization : In this each entry in the corpus will be broken into set of words
sample['text_final']= [word_tokenize(entry) for entry in sample['text_final']]
# Step - d : Remove Stop words, Non-Numeric and perfom Word Stemming/Lemmenting.
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV
for index,entry in enumerate(sample['text_final']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'title_final'
    sample.loc[index,'text_final'] = str(Final_words)

# %%
#dividing in train (70% of the dataset) and test set (30% of the dataset)
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(sample['text_final'],sample[['gender','religion','ethnicity','ideology']],test_size=0.3)

Encoder = LabelEncoder()

#word vectorization
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(sample["text_final"])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

#Label encode the target variable — 
#This is done to transform Categorical data of string type in the data set 
#into numerical values which the model can understand.

#gender
Train_Y_gender = Encoder.fit_transform(Train_Y['gender'])
Test_Y_gender = Encoder.fit_transform(Test_Y['gender'])

#religion
Train_Y_rel = Encoder.fit_transform(Train_Y['religion'])
Test_Y_rel = Encoder.fit_transform(Test_Y['religion'])

#ethnicity
Train_Y_ethn = Encoder.fit_transform(Train_Y['ethnicity'])
Test_Y_ethn = Encoder.fit_transform(Test_Y['ethnicity'])

#ideology
Train_Y_id = Encoder.fit_transform(Train_Y['ideology'])
Test_Y_id = Encoder.fit_transform(Test_Y['ideology'])

#stacking into a vector
y_train=np.stack((Train_Y_gender,Train_Y_rel,Train_Y_ethn,Train_Y_id),axis=1)
y_test=np.stack((Test_Y_gender,Test_Y_rel,Test_Y_ethn,Test_Y_id),axis=1)

# %%
#using we can use the argument class_weight='balanced'  
#to penalize mistakes on the minority class by an amount proportional to how under-represented it is.
SVM = svm.SVC(C=1.0, kernel='linear',class_weight='balanced',gamma='auto',probability=True)
# Create the Multioutput Classifier
mor = MultiOutputClassifier(SVM)
# Train the regressor
mor.fit(Train_X_Tfidf, y_train)
# Generate predictions for testing data
y_pred = mor.predict(Test_X_Tfidf)

# %%
print("SVM Metrics for Gender")
print(f"The F1 score is {f1_score(y_test[:,0], y_pred[:,0], average='weighted')}")
# Out:
# SVM Metrics for Gender
# The F1 score is 0.7347725835749166

# %%
print("SVM Metrics for Religion")
print(f"The F1 score is {f1_score(y_test[:,1], y_pred[:,1], average='weighted')}")
# Out:
# SVM Metrics for Religion
# The F1 score is 0.46039262198547665

# %%
print("SVM Metrics for Ethnicity")
print(f"The F1 score is {f1_score(y_test[:,2], y_pred[:,2], average='weighted')}")
# Out:
# SVM Metrics for Ethnicity
# The F1 score is 0.49924455087338576

# %%
print("SVM Accuracy Score Ideology")
print(f"The F1 score is {f1_score(y_test[:,3], y_pred[:,3], average='weighted')}")
# Out:
# SVM Accuracy Score Ideology
# The F1 score is 0.3668035939992256
